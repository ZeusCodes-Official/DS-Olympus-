# %% [markdown]
# ![Employee-retention.jpg](attachment:Employee-retention.jpg)

# %% [markdown]
# # Imorting Required Libraries:

# %%
import pandas as pd
import numpy as np
import lux
import seaborn as sns
import matplotlib.pyplot as plt

# %%
lux.logger=True

# %% [markdown]
# # Exploratory Data Analysis:

# %%
df=pd.read_csv("HR_comma_sep.csv")

# %%
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df.intent=['left']
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df.info()
# Out:
# <class 'lux.core.frame.LuxDataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df.tail()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years
# count           14999.000000
# mean                0.021268
# std                 0.144281
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 1.000000

# %%
df['Work_accident'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['promotion_last_5years'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['sales'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
sns.countplot(x='left',data=df)
plt.show()

# %%
df['left']
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
sns.countplot(x='salary',data=df)
plt.show()

# %%
df['salary']
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
sns.catplot(x='left',col='salary',kind='count',data=df)

# %%
sns.countplot(x='promotion_last_5years',data=df)
plt.show()

# %%
sns.catplot(x='left',col='promotion_last_5years',kind='count',data=df)

# %%
sns.countplot(x='Work_accident',data=df)
plt.show()

# %%
sns.catplot(x='left',col='Work_accident',kind='count',data=df)

# %%
fig=plt.subplots(figsize=(14,7))
sns.countplot(x='sales',data=df)
plt.show()

# %%
sns.catplot(x='left',col='sales',kind='count',data=df)

# %%
sns.displot(df['satisfaction_level'])

# %%
sns.boxplot(x='left',y='satisfaction_level',data=df)
# Out:
# <AxesSubplot:xlabel='left', ylabel='satisfaction_level'>

# %%
sns.distplot(df['number_project'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:`distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='number_project', ylabel='Density'>

# %%
sns.boxplot(x='left',y='number_project',data=df)
# Out:
# <AxesSubplot:xlabel='left', ylabel='number_project'>

# %%
sns.distplot(df['last_evaluation'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:`distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='last_evaluation', ylabel='Density'>

# %%
sns.boxplot(x='left',y='last_evaluation',data=df)
# Out:
# <AxesSubplot:xlabel='left', ylabel='last_evaluation'>

# %%
sns.distplot(df['average_montly_hours'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:`distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='average_montly_hours', ylabel='Density'>

# %%
sns.boxplot(x='left',y='average_montly_hours',data=df)
# Out:
# <AxesSubplot:xlabel='left', ylabel='average_montly_hours'>

# %%
sns.distplot(df['time_spend_company'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:`distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='time_spend_company', ylabel='Density'>

# %%
sns.boxplot(x='left',y='time_spend_company',data=df)
# Out:
# <AxesSubplot:xlabel='left', ylabel='time_spend_company'>

# %%
cor_mat=df.corr()

# %%
cor_mat
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
fig=plt.figure(figsize=(18,8))
sns.heatmap(cor_mat,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %% [markdown]
# # Feture Engineering:

# %%
df2=df.copy()

# %%
df2.head()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df2.isnull().sum()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df2.drop(['sales'],axis=1,inplace=True)

# %%
df2.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'salary'],
#       dtype='object')

# %%
df2['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
salary_dummies=pd.get_dummies(df2['salary'],drop_first=True)

# %%
salary_dummies
# Out:
#        low  medium
# 0        1       0
# 1        0       1
# 2        0       1
# 3        1       0
# 4        1       0
# ...    ...     ...
# 14994    1       0
# 14995    1       0
# 14996    1       0
# 14997    1       0
# 14998    1       0
#
# [14999 rows x 2 columns]

# %%
df2=pd.concat([df2,salary_dummies],axis=1)

# %%
df2.head()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df2.drop(['salary'],axis=1,inplace=True)

# %%
df2.head()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %% [markdown]
# # Train-Test Split:

# %%
x=df2.drop(labels='left',axis=1)
y=df2['left']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=14)

# %%
len(X_train)
# Out:
# 10499

# %%
len(X_test)
# Out:
# 4500

# %% [markdown]
# #  Hyper Parameter Tuning for model selection:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import svm
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB

# %%
model_params={
    
    'random_forest':{
        'model':RandomForestClassifier(),
        'params':{
            'n_estimators':[14,28,9]
        }
        
    },
    
    'logistic_regression':{
        'model':LogisticRegression(solver='liblinear',multi_class='auto'),
        'params':{
            'C':[14,28,9]
        }
    }
        
    
}

# %%
scores=[]
for model_name,mp in model_params.items():
    clf=GridSearchCV(mp['model'],mp['params'],cv=5,return_train_score=False)
    clf.fit(X_train,y_train)
    scores.append({
        'model':model_name,
        'best_score':clf.best_score_,
        'best_params':clf.best_params_
    })

# %%
df=pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py:918: UserWarning:
# Unexpected error in rendering Lux widget and recommendations. Falling back to Pandas display.
# Please report the following issue on Github: https://github.com/lux-org/lux/issues
#
# C:\ProgramData\Anaconda3\lib\site-packages\lux\core\frame.py:609: UserWarning:Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\lux\core\frame.py", line 558, in _ipython_display_
#     self.maintain_metadata()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\lux\core\frame.py", line 134, in maintain_metadata
#     lux.config.executor.compute_stats(self)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\lux\executor\PandasExecutor.py", line 541, in compute_stats
#     ldf.unique_values[attribute_repr] = list(ldf[attribute].unique())
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py", line 1872, in unique
#     result = super().unique()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py", line 1047, in unique
#     result = unique1d(values)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py", line 407, in unique
#     uniques = table.unique(values)
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4719, in pandas._libs.hashtable.PyObjectHashTable.unique
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4666, in pandas._libs.hashtable.PyObjectHashTable._unique
# TypeError: unhashable type: 'dict'
#                  model  best_score           best_params
# 0        random_forest    0.988380  {'n_estimators': 28}
# 1  logistic_regression    0.783789             {'C': 14}

# %% [markdown]
# ### Model Implementation Using Rndom Forest Classifier:

# %%
model=RandomForestClassifier(n_estimators=28,bootstrap=True,max_features='sqrt')
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_features='sqrt', n_estimators=28)

# %%
model.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1404003305),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1776391119),
#  DecisionTreeClassifier(max_features='sqrt', random_state=381365690),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1926444954),
#  DecisionTreeClassifier(max_features='sqrt', random_state=550281813),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2130387772),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1050958757),
#  DecisionTreeClassifier(max_features='sqrt', random_state=613772522),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1726848470),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1131265962),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1979884939),
#  DecisionTreeClassifier(max_features='sqrt', random_state=411710259),
#  DecisionTreeClassifier(max_features='sqrt', random_state=527988789),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1204839526),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1899579058),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1038810072),
#  DecisionTreeClassifier(max_features='sqrt', random_state=6016692),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1803200709),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1995735736),
#  DecisionTreeClassifier(max_features='sqrt', random_state=190767010),
#  DecisionTreeClassifier(max_features='sqrt', random_state=632123464),
#  DecisionTreeClassifier(max_features='sqrt', random_state=786605757),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1691021056),
#  DecisionTreeClassifier(max_features='sqrt', random_state=984096065),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1819300208),
#  DecisionTreeClassifier(max_features='sqrt', random_state=968748796),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1793963333),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1589153965)]

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(model.estimators_[1],filled=True)
# Out:
# [Text(299.4161405964351, 530.6571428571428, 'X[2] <= 2.5\ngini = 0.355\nsamples = 6586\nvalue = [8075, 2424]'),
#  Text(87.41064899451554, 504.7714285714286, 'X[0] <= 0.465\ngini = 0.466\nsamples = 1060\nvalue = [617, 1053]'),
#  Text(48.00891224862888, 478.8857142857143, 'X[1] <= 0.575\ngini = 0.247\nsamples = 761\nvalue = [173, 1026]'),
#  Text(30.22074954296161, 453.0, 'X[3] <= 162.0\ngini = 0.121\nsamples = 694\nvalue = [71, 1023]'),
#  Text(19.12705667276051, 427.11428571428576, 'X[0] <= 0.355\ngini = 0.071\nsamples = 670\nvalue = [39, 1020]'),
#  Text(6.120658135283364, 401.22857142857146, 'X[7] <= 0.5\ngini = 0.142\nsamples = 9\nvalue = [12, 1]'),
#  Text(3.060329067641682, 375.34285714285716, 'gini = 0.0\nsamples = 5\nvalue = [8, 0]'),
#  Text(9.180987202925046, 375.34285714285716, 'X[4] <= 4.5\ngini = 0.32\nsamples = 4\nvalue = [4, 1]'),
#  Text(6.120658135283364, 349.4571428571429, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(12.241316270566728, 349.4571428571429, 'X[0] <= 0.305\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(9.180987202925046, 323.57142857142856, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(15.30164533820841, 323.57142857142856, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(32.133455210237656, 401.22857142857146, 'X[3] <= 125.5\ngini = 0.05\nsamples = 661\nvalue = [27, 1019]'),
#  Text(29.073126142595978, 375.34285714285716, 'gini = 0.0\nsamples = 7\nvalue = [11, 0]'),
#  Text(35.193784277879345, 375.34285714285716, 'X[4] <= 3.5\ngini = 0.03\nsamples = 654\nvalue = [16, 1019]'),
#  Text(32.133455210237656, 349.4571428571429, 'X[3] <= 135.5\ngini = 0.012\nsamples = 650\nvalue = [6, 1019]'),
#  Text(21.422303473491773, 323.57142857142856, 'X[1] <= 0.565\ngini = 0.022\nsamples = 172\nvalue = [3, 261]'),
#  Text(15.30164533820841, 297.6857142857143, 'X[0] <= 0.365\ngini = 0.009\nsamples = 153\nvalue = [1, 232]'),
#  Text(12.241316270566728, 271.8, 'X[5] <= 0.5\ngini = 0.165\nsamples = 9\nvalue = [1, 10]'),
#  Text(9.180987202925046, 245.9142857142857, 'gini = 0.0\nsamples = 8\nvalue = [0, 10]'),
#  Text(15.30164533820841, 245.9142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(18.36197440585009, 271.8, 'gini = 0.0\nsamples = 144\nvalue = [0, 222]'),
#  Text(27.542961608775137, 297.6857142857143, 'X[3] <= 131.5\ngini = 0.121\nsamples = 19\nvalue = [2, 29]'),
#  Text(24.482632541133455, 271.8, 'gini = 0.0\nsamples = 10\nvalue = [0, 16]'),
#  Text(30.60329067641682, 271.8, 'X[0] <= 0.41\ngini = 0.231\nsamples = 9\nvalue = [2, 13]'),
#  Text(27.542961608775137, 245.9142857142857, 'X[0] <= 0.38\ngini = 0.48\nsamples = 4\nvalue = [2, 3]'),
#  Text(24.482632541133455, 220.02857142857147, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(30.60329067641682, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(33.6636197440585, 245.9142857142857, 'gini = 0.0\nsamples = 5\nvalue = [0, 10]'),
#  Text(42.844606946983546, 323.57142857142856, 'X[8] <= 0.5\ngini = 0.008\nsamples = 478\nvalue = [3, 758]'),
#  Text(39.784277879341865, 297.6857142857143, 'X[1] <= 0.44\ngini = 0.012\nsamples = 304\nvalue = [3, 481]'),
#  Text(36.72394881170018, 271.8, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(42.844606946983546, 271.8, 'X[0] <= 0.415\ngini = 0.004\nsamples = 303\nvalue = [1, 481]'),
#  Text(39.784277879341865, 245.9142857142857, 'gini = 0.0\nsamples = 169\nvalue = [0, 261]'),
#  Text(45.90493601462523, 245.9142857142857, 'X[5] <= 0.5\ngini = 0.009\nsamples = 134\nvalue = [1, 220]'),
#  Text(42.844606946983546, 220.02857142857147, 'X[3] <= 150.5\ngini = 0.01\nsamples = 124\nvalue = [1, 203]'),
#  Text(39.784277879341865, 194.14285714285717, 'gini = 0.0\nsamples = 81\nvalue = [0, 138]'),
#  Text(45.90493601462523, 194.14285714285717, 'X[1] <= 0.505\ngini = 0.03\nsamples = 43\nvalue = [1, 65]'),
#  Text(42.844606946983546, 168.25714285714287, 'X[7] <= 0.5\ngini = 0.071\nsamples = 20\nvalue = [1, 26]'),
#  Text(39.784277879341865, 142.37142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(45.90493601462523, 142.37142857142857, 'X[1] <= 0.495\ngini = 0.074\nsamples = 19\nvalue = [1, 25]'),
#  Text(42.844606946983546, 116.48571428571432, 'gini = 0.0\nsamples = 17\nvalue = [0, 24]'),
#  Text(48.96526508226691, 116.48571428571432, 'X[0] <= 0.44\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(45.90493601462523, 90.60000000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(52.02559414990859, 90.60000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(48.96526508226691, 168.25714285714287, 'gini = 0.0\nsamples = 23\nvalue = [0, 39]'),
#  Text(48.96526508226691, 220.02857142857147, 'gini = 0.0\nsamples = 10\nvalue = [0, 17]'),
#  Text(45.90493601462523, 297.6857142857143, 'gini = 0.0\nsamples = 174\nvalue = [0, 277]'),
#  Text(38.25411334552102, 349.4571428571429, 'gini = 0.0\nsamples = 4\nvalue = [10, 0]'),
#  Text(41.31444241316271, 427.11428571428576, 'X[3] <= 242.5\ngini = 0.157\nsamples = 24\nvalue = [32, 3]'),
#  Text(38.25411334552102, 401.22857142857146, 'gini = 0.0\nsamples = 19\nvalue = [27, 0]'),
#  Text(44.374771480804384, 401.22857142857146, 'X[8] <= 0.5\ngini = 0.469\nsamples = 5\nvalue = [5, 3]'),
#  Text(41.31444241316271, 375.34285714285716, 'gini = 0.0\nsamples = 2\nvalue = [5, 0]'),
#  Text(47.43510054844607, 375.34285714285716, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(65.79707495429616, 453.0, 'X[3] <= 280.0\ngini = 0.056\nsamples = 67\nvalue = [102, 3]'),
#  Text(59.6764168190128, 427.11428571428576, 'X[3] <= 151.5\ngini = 0.038\nsamples = 65\nvalue = [100, 2]'),
#  Text(56.61608775137111, 401.22857142857146, 'X[1] <= 0.755\ngini = 0.097\nsamples = 22\nvalue = [37, 2]'),
#  Text(53.55575868372944, 375.34285714285716, 'gini = 0.0\nsamples = 13\nvalue = [25, 0]'),
#  Text(59.6764168190128, 375.34285714285716, 'X[8] <= 0.5\ngini = 0.245\nsamples = 9\nvalue = [12, 2]'),
#  Text(56.61608775137111, 349.4571428571429, 'X[1] <= 0.79\ngini = 0.444\nsamples = 5\nvalue = [4, 2]'),
#  Text(53.55575868372944, 323.57142857142856, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(59.6764168190128, 323.57142857142856, 'gini = 0.0\nsamples = 3\nvalue = [4, 0]'),
#  Text(62.736745886654475, 349.4571428571429, 'gini = 0.0\nsamples = 4\nvalue = [8, 0]'),
#  Text(62.736745886654475, 401.22857142857146, 'gini = 0.0\nsamples = 43\nvalue = [63, 0]'),
#  Text(71.91773308957953, 427.11428571428576, 'X[0] <= 0.41\ngini = 0.444\nsamples = 2\nvalue = [2, 1]'),
#  Text(68.85740402193784, 401.22857142857146, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(74.9780621572212, 401.22857142857146, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(126.81238574040219, 478.8857142857143, 'X[3] <= 273.5\ngini = 0.108\nsamples = 299\nvalue = [444, 27]'),
#  Text(96.01782449725776, 453.0, 'X[3] <= 154.5\ngini = 0.089\nsamples = 287\nvalue = [431, 21]'),
#  Text(92.95749542961609, 427.11428571428576, 'gini = 0.0\nsamples = 74\nvalue = [107, 0]'),
#  Text(99.07815356489945, 427.11428571428576, 'X[0] <= 0.485\ngini = 0.114\nsamples = 213\nvalue = [324, 21]'),
#  Text(81.09872029250457, 401.22857142857146, 'X[5] <= 0.5\ngini = 0.42\nsamples = 6\nvalue = [7, 3]'),
#  Text(78.03839122486289, 375.34285714285716, 'X[8] <= 0.5\ngini = 0.375\nsamples = 3\nvalue = [1, 3]'),
#  Text(74.9780621572212, 349.4571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(81.09872029250457, 349.4571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]'),
#  Text(84.15904936014626, 375.34285714285716, 'gini = 0.0\nsamples = 3\nvalue = [6, 0]'),
#  Text(117.05758683729434, 401.22857142857146, 'X[4] <= 4.5\ngini = 0.102\nsamples = 207\nvalue = [317, 18]'),
#  Text(100.9908592321755, 375.34285714285716, 'X[3] <= 252.5\ngini = 0.043\nsamples = 170\nvalue = [265, 6]'),
#  Text(87.21937842778793, 349.4571428571429, 'X[0] <= 0.795\ngini = 0.027\nsamples = 137\nvalue = [220, 3]'),
#  Text(74.9780621572212, 323.57142857142856, 'X[4] <= 3.5\ngini = 0.012\nsamples = 101\nvalue = [163, 1]'),
#  Text(71.91773308957953, 297.6857142857143, 'gini = 0.0\nsamples = 84\nvalue = [135, 0]'),
#  Text(78.03839122486289, 297.6857142857143, 'X[0] <= 0.615\ngini = 0.067\nsamples = 17\nvalue = [28, 1]'),
#  Text(74.9780621572212, 271.8, 'gini = 0.0\nsamples = 8\nvalue = [16, 0]'),
#  Text(81.09872029250457, 271.8, 'X[1] <= 0.705\ngini = 0.142\nsamples = 9\nvalue = [12, 1]'),
#  Text(78.03839122486289, 245.9142857142857, 'gini = 0.0\nsamples = 6\nvalue = [10, 0]'),
#  Text(84.15904936014626, 245.9142857142857, 'X[0] <= 0.655\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(81.09872029250457, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(87.21937842778793, 220.02857142857147, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(99.46069469835466, 323.57142857142856, 'X[1] <= 0.825\ngini = 0.065\nsamples = 36\nvalue = [57, 2]'),
#  Text(96.40036563071298, 297.6857142857143, 'gini = 0.0\nsamples = 20\nvalue = [39, 0]'),
#  Text(102.52102376599635, 297.6857142857143, 'X[3] <= 216.0\ngini = 0.18\nsamples = 16\nvalue = [18, 2]'),
#  Text(99.46069469835466, 271.8, 'X[0] <= 0.855\ngini = 0.346\nsamples = 8\nvalue = [7, 2]'),
#  Text(96.40036563071298, 245.9142857142857, 'X[7] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(93.3400365630713, 220.02857142857147, 'X[3] <= 167.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(90.27970749542962, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(96.40036563071298, 194.14285714285717, 'X[8] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(93.3400365630713, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(99.46069469835466, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(99.46069469835466, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(102.52102376599635, 245.9142857142857, 'gini = 0.0\nsamples = 4\nvalue = [5, 0]'),
#  Text(105.58135283363802, 271.8, 'gini = 0.0\nsamples = 8\nvalue = [11, 0]'),
#  Text(114.76234003656307, 349.4571428571429, 'X[1] <= 0.49\ngini = 0.117\nsamples = 33\nvalue = [45, 3]'),
#  Text(111.70201096892139, 323.57142857142856, 'X[7] <= 0.5\ngini = 0.48\nsamples = 3\nvalue = [2, 3]'),
#  Text(108.64168190127971, 297.6857142857143, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(114.76234003656307, 297.6857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]'),
#  Text(117.82266910420475, 323.57142857142856, 'gini = 0.0\nsamples = 30\nvalue = [43, 0]'),
#  Text(133.12431444241315, 375.34285714285716, 'X[0] <= 0.87\ngini = 0.305\nsamples = 37\nvalue = [52, 12]'),
#  Text(127.0036563071298, 349.4571428571429, 'X[3] <= 156.0\ngini = 0.145\nsamples = 30\nvalue = [47, 4]'),
#  Text(123.94332723948811, 323.57142857142856, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(130.06398537477148, 323.57142857142856, 'X[0] <= 0.615\ngini = 0.113\nsamples = 29\nvalue = [47, 3]'),
#  Text(127.0036563071298, 297.6857142857143, 'X[4] <= 6.0\ngini = 0.305\nsamples = 11\nvalue = [13, 3]'),
#  Text(123.94332723948811, 271.8, 'X[3] <= 168.0\ngini = 0.5\nsamples = 5\nvalue = [3, 3]'),
#  Text(120.88299817184644, 245.9142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(127.0036563071298, 245.9142857142857, 'X[5] <= 0.5\ngini = 0.375\nsamples = 3\nvalue = [3, 1]'),
#  Text(123.94332723948811, 220.02857142857147, 'X[1] <= 0.82\ngini = 0.444\nsamples = 2\nvalue = [2, 1]'),
#  Text(120.88299817184644, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(127.0036563071298, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(130.06398537477148, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(130.06398537477148, 271.8, 'gini = 0.0\nsamples = 6\nvalue = [10, 0]'),
#  Text(133.12431444241315, 297.6857142857143, 'gini = 0.0\nsamples = 18\nvalue = [34, 0]'),
#  Text(139.24497257769653, 349.4571428571429, 'X[8] <= 0.5\ngini = 0.473\nsamples = 7\nvalue = [5, 8]'),
#  Text(136.18464351005485, 323.57142857142856, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(142.3053016453382, 323.57142857142856, 'X[1] <= 0.94\ngini = 0.397\nsamples = 5\nvalue = [3, 8]'),
#  Text(139.24497257769653, 297.6857142857143, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(145.36563071297988, 297.6857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 8]'),
#  Text(157.6069469835466, 453.0, 'X[6] <= 0.5\ngini = 0.432\nsamples = 12\nvalue = [13, 6]'),
#  Text(154.54661791590493, 427.11428571428576, 'X[0] <= 0.745\ngini = 0.444\nsamples = 11\nvalue = [12, 6]'),
#  Text(151.48628884826326, 401.22857142857146, 'X[8] <= 0.5\ngini = 0.48\nsamples = 6\nvalue = [4, 6]'),
#  Text(148.42595978062158, 375.34285714285716, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(154.54661791590493, 375.34285714285716, 'X[3] <= 281.5\ngini = 0.5\nsamples = 5\nvalue = [4, 4]'),
#  Text(151.48628884826326, 349.4571428571429, 'X[0] <= 0.695\ngini = 0.32\nsamples = 3\nvalue = [1, 4]'),
#  Text(148.42595978062158, 323.57142857142856, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(154.54661791590493, 323.57142857142856, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]'),
#  Text(157.6069469835466, 349.4571428571429, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(157.6069469835466, 401.22857142857146, 'gini = 0.0\nsamples = 5\nvalue = [8, 0]'),
#  Text(160.6672760511883, 427.11428571428576, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(511.42163219835464, 504.7714285714286, 'X[1] <= 0.765\ngini = 0.262\nsamples = 5526\nvalue = [7458, 1371]'),
#  Text(319.46966407678246, 478.8857142857143, 'X[3] <= 290.5\ngini = 0.04\nsamples = 2825\nvalue = [4454, 93]'),
#  Text(316.40933500914076, 453.0, 'X[2] <= 6.5\ngini = 0.035\nsamples = 2816\nvalue = [4454, 80]'),
#  Text(313.34900594149906, 427.11428571428576, 'X[2] <= 5.5\ngini = 0.032\nsamples = 2813\nvalue = [4454, 73]'),
#  Text(245.68704296160877, 401.22857142857146, 'X[4] <= 3.5\ngini = 0.027\nsamples = 2666\nvalue = [4254, 59]'),
#  Text(199.30393053016454, 375.34285714285716, 'X[3] <= 179.5\ngini = 0.017\nsamples = 1916\nvalue = [3094, 26]'),
#  Text(175.2038391224863, 349.4571428571429, 'X[5] <= 0.5\ngini = 0.031\nsamples = 729\nvalue = [1170, 19]'),
#  Text(172.1435100548446, 323.57142857142856, 'X[4] <= 2.5\ngini = 0.039\nsamples = 594\nvalue = [942, 19]'),
#  Text(151.48628884826326, 297.6857142857143, 'X[1] <= 0.475\ngini = 0.056\nsamples = 249\nvalue = [368, 11]'),
#  Text(140.77513711151738, 271.8, 'X[1] <= 0.445\ngini = 0.198\nsamples = 21\nvalue = [32, 4]'),
#  Text(137.71480804387568, 245.9142857142857, 'gini = 0.0\nsamples = 14\nvalue = [22, 0]'),
#  Text(143.83546617915906, 245.9142857142857, 'X[0] <= 0.22\ngini = 0.408\nsamples = 7\nvalue = [10, 4]'),
#  Text(140.77513711151738, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [0, 3]'),
#  Text(146.89579524680073, 220.02857142857147, 'X[7] <= 0.5\ngini = 0.165\nsamples = 6\nvalue = [10, 1]'),
#  Text(143.83546617915906, 194.14285714285717, 'gini = 0.0\nsamples = 2\nvalue = [5, 0]'),
#  Text(149.9561243144424, 194.14285714285717, 'X[2] <= 3.5\ngini = 0.278\nsamples = 4\nvalue = [5, 1]'),
#  Text(146.89579524680073, 168.25714285714287, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(153.01645338208408, 168.25714285714287, 'X[0] <= 0.54\ngini = 0.444\nsamples = 2\nvalue = [2, 1]'),
#  Text(149.9561243144424, 142.37142857142857, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(156.07678244972578, 142.37142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(162.19744058500913, 271.8, 'X[1] <= 0.665\ngini = 0.04\nsamples = 228\nvalue = [336, 7]'),
#  Text(159.13711151736746, 245.9142857142857, 'gini = 0.0\nsamples = 137\nvalue = [218, 0]'),
#  Text(165.25776965265084, 245.9142857142857, 'X[1] <= 0.675\ngini = 0.106\nsamples = 91\nvalue = [118, 7]'),
#  Text(159.13711151736746, 220.02857142857147, 'X[0] <= 0.415\ngini = 0.346\nsamples = 13\nvalue = [14, 4]'),
#  Text(156.07678244972578, 194.14285714285717, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]'),
#  Text(162.19744058500913, 194.14285714285717, 'gini = 0.0\nsamples = 11\nvalue = [14, 0]'),
#  Text(171.37842778793419, 220.02857142857147, 'X[0] <= 0.55\ngini = 0.055\nsamples = 78\nvalue = [104, 3]'),
#  Text(168.3180987202925, 194.14285714285717, 'X[0] <= 0.535\ngini = 0.185\nsamples = 22\nvalue = [26, 3]'),
#  Text(165.25776965265084, 168.25714285714287, 'gini = 0.0\nsamples = 16\nvalue = [23, 0]'),
#  Text(171.37842778793419, 168.25714285714287, 'X[3] <= 166.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(168.3180987202925, 142.37142857142857, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(174.43875685557586, 142.37142857142857, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(174.43875685557586, 194.14285714285717, 'gini = 0.0\nsamples = 56\nvalue = [78, 0]'),
#  Text(192.80073126142597, 297.6857142857143, 'X[8] <= 0.5\ngini = 0.027\nsamples = 345\nvalue = [574, 8]'),
#  Text(186.6800731261426, 271.8, 'X[0] <= 0.775\ngini = 0.027\nsamples = 215\nvalue = [354, 5]'),
#  Text(183.6197440585009, 245.9142857142857, 'gini = 0.0\nsamples = 125\nvalue = [214, 0]'),
#  Text(189.7404021937843, 245.9142857142857, 'X[6] <= 0.5\ngini = 0.067\nsamples = 90\nvalue = [140, 5]'),
#  Text(183.6197440585009, 220.02857142857147, 'X[2] <= 3.5\ngini = 0.056\nsamples = 85\nvalue = [136, 4]'),
#  Text(180.55941499085924, 194.14285714285717, 'X[1] <= 0.655\ngini = 0.124\nsamples = 33\nvalue = [56, 4]'),
#  Text(177.49908592321754, 168.25714285714287, 'gini = 0.0\nsamples = 15\nvalue = [28, 0]'),
#  Text(183.6197440585009, 168.25714285714287, 'X[3] <= 162.5\ngini = 0.219\nsamples = 18\nvalue = [28, 4]'),
#  Text(180.55941499085924, 142.37142857142857, 'gini = 0.0\nsamples = 7\nvalue = [13, 0]'),
#  Text(186.6800731261426, 142.37142857142857, 'X[0] <= 0.785\ngini = 0.332\nsamples = 11\nvalue = [15, 4]'),
#  Text(183.6197440585009, 116.48571428571432, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]'),
#  Text(189.7404021937843, 116.48571428571432, 'gini = 0.0\nsamples = 9\nvalue = [15, 0]'),
#  Text(186.6800731261426, 194.14285714285717, 'gini = 0.0\nsamples = 52\nvalue = [80, 0]'),
#  Text(195.86106032906764, 220.02857142857147, 'X[3] <= 137.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(192.80073126142597, 194.14285714285717, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(198.92138939670932, 194.14285714285717, 'X[1] <= 0.605\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(195.86106032906764, 168.25714285714287, 'X[0] <= 0.895\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(192.80073126142597, 142.37142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(198.92138939670932, 142.37142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(201.981718464351, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(198.92138939670932, 271.8, 'X[0] <= 0.145\ngini = 0.027\nsamples = 130\nvalue = [220, 3]'),
#  Text(195.86106032906764, 245.9142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 3]'),
#  Text(201.981718464351, 245.9142857142857, 'gini = 0.0\nsamples = 129\nvalue = [220, 0]'),
#  Text(178.26416819012798, 323.57142857142856, 'gini = 0.0\nsamples = 135\nvalue = [228, 0]'),
#  Text(223.40402193784277, 349.4571428571429, 'X[3] <= 236.5\ngini = 0.007\nsamples = 1187\nvalue = [1924, 7]'),
#  Text(220.3436928702011, 323.57142857142856, 'gini = 0.0\nsamples = 702\nvalue = [1149, 0]'),
#  Text(226.46435100548445, 323.57142857142856, 'X[0] <= 0.365\ngini = 0.018\nsamples = 485\nvalue = [775, 7]'),
#  Text(217.28336380255942, 297.6857142857143, 'X[0] <= 0.355\ngini = 0.188\nsamples = 19\nvalue = [34, 4]'),
#  Text(214.22303473491775, 271.8, 'X[2] <= 4.5\ngini = 0.056\nsamples = 18\nvalue = [34, 1]'),
#  Text(211.16270566727604, 245.9142857142857, 'X[2] <= 3.5\ngini = 0.105\nsamples = 10\nvalue = [17, 1]'),
#  Text(208.10237659963437, 220.02857142857147, 'gini = 0.0\nsamples = 5\nvalue = [12, 0]'),
#  Text(214.22303473491775, 220.02857142857147, 'X[1] <= 0.635\ngini = 0.278\nsamples = 5\nvalue = [5, 1]'),
#  Text(211.16270566727604, 194.14285714285717, 'X[4] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(208.10237659963437, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(214.22303473491775, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(217.28336380255942, 194.14285714285717, 'gini = 0.0\nsamples = 3\nvalue = [4, 0]'),
#  Text(217.28336380255942, 245.9142857142857, 'gini = 0.0\nsamples = 8\nvalue = [17, 0]'),
#  Text(220.3436928702011, 271.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 3]'),
#  Text(235.6453382084095, 297.6857142857143, 'X[0] <= 0.855\ngini = 0.008\nsamples = 466\nvalue = [741, 3]'),
#  Text(226.46435100548445, 271.8, 'X[0] <= 0.585\ngini = 0.004\nsamples = 338\nvalue = [544, 1]'),
#  Text(223.40402193784277, 245.9142857142857, 'X[0] <= 0.575\ngini = 0.013\nsamples = 99\nvalue = [155, 1]'),
#  Text(220.3436928702011, 220.02857142857147, 'gini = 0.0\nsamples = 94\nvalue = [149, 0]'),
#  Text(226.46435100548445, 220.02857142857147, 'X[7] <= 0.5\ngini = 0.245\nsamples = 5\nvalue = [6, 1]'),
#  Text(223.40402193784277, 194.14285714285717, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]'),
#  Text(229.52468007312615, 194.14285714285717, 'X[1] <= 0.685\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(226.46435100548445, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(232.58500914076782, 168.25714285714287, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(229.52468007312615, 245.9142857142857, 'gini = 0.0\nsamples = 239\nvalue = [389, 0]'),
#  Text(244.82632541133455, 271.8, 'X[2] <= 4.5\ngini = 0.02\nsamples = 128\nvalue = [197, 2]'),
#  Text(241.76599634369288, 245.9142857142857, 'gini = 0.0\nsamples = 95\nvalue = [151, 0]'),
#  Text(247.88665447897623, 245.9142857142857, 'X[0] <= 0.865\ngini = 0.08\nsamples = 33\nvalue = [46, 2]'),
#  Text(244.82632541133455, 220.02857142857147, 'X[3] <= 268.0\ngini = 0.408\nsamples = 5\nvalue = [5, 2]'),
#  Text(241.76599634369288, 194.14285714285717, 'X[3] <= 254.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(238.7056672760512, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(244.82632541133455, 168.25714285714287, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(247.88665447897623, 194.14285714285717, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]'),
#  Text(250.9469835466179, 220.02857142857147, 'gini = 0.0\nsamples = 28\nvalue = [41, 0]'),
#  Text(292.070155393053, 375.34285714285716, 'X[7] <= 0.5\ngini = 0.054\nsamples = 750\nvalue = [1160, 33]'),
#  Text(267.7787934186472, 349.4571428571429, 'X[4] <= 4.5\ngini = 0.023\nsamples = 433\nvalue = [682, 8]'),
#  Text(257.06764168190125, 323.57142857142856, 'X[0] <= 0.555\ngini = 0.006\nsamples = 213\nvalue = [358, 1]'),
#  Text(254.0073126142596, 297.6857142857143, 'X[0] <= 0.545\ngini = 0.015\nsamples = 73\nvalue = [132, 1]'),
#  Text(250.9469835466179, 271.8, 'gini = 0.0\nsamples = 69\nvalue = [125, 0]'),
#  Text(257.06764168190125, 271.8, 'X[3] <= 182.0\ngini = 0.219\nsamples = 4\nvalue = [7, 1]'),
#  Text(254.0073126142596, 245.9142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(260.12797074954295, 245.9142857142857, 'gini = 0.0\nsamples = 3\nvalue = [7, 0]'),
#  Text(260.12797074954295, 297.6857142857143, 'gini = 0.0\nsamples = 140\nvalue = [226, 0]'),
#  Text(278.48994515539306, 323.57142857142856, 'X[3] <= 274.5\ngini = 0.041\nsamples = 220\nvalue = [324, 7]'),
#  Text(272.3692870201097, 297.6857142857143, 'X[1] <= 0.575\ngini = 0.013\nsamples = 208\nvalue = [307, 2]'),
#  Text(269.308957952468, 271.8, 'X[1] <= 0.565\ngini = 0.029\nsamples = 92\nvalue = [135, 2]'),
#  Text(266.2486288848263, 245.9142857142857, 'gini = 0.0\nsamples = 88\nvalue = [133, 0]'),
#  Text(272.3692870201097, 245.9142857142857, 'X[4] <= 6.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(269.308957952468, 220.02857142857147, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(275.42961608775136, 220.02857142857147, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(275.42961608775136, 271.8, 'gini = 0.0\nsamples = 116\nvalue = [172, 0]'),
#  Text(284.6106032906764, 297.6857142857143, 'X[0] <= 0.515\ngini = 0.351\nsamples = 12\nvalue = [17, 5]'),
#  Text(281.55027422303476, 271.8, 'gini = 0.0\nsamples = 6\nvalue = [10, 0]'),
#  Text(287.6709323583181, 271.8, 'X[5] <= 0.5\ngini = 0.486\nsamples = 6\nvalue = [7, 5]'),
#  Text(284.6106032906764, 245.9142857142857, 'X[0] <= 0.65\ngini = 0.496\nsamples = 5\nvalue = [6, 5]'),
#  Text(281.55027422303476, 220.02857142857147, 'X[0] <= 0.555\ngini = 0.469\nsamples = 3\nvalue = [3, 5]'),
#  Text(278.48994515539306, 194.14285714285717, 'X[3] <= 281.5\ngini = 0.48\nsamples = 2\nvalue = [3, 2]'),
#  Text(275.42961608775136, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(281.55027422303476, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [3, 0]'),
#  Text(284.6106032906764, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [0, 3]'),
#  Text(287.6709323583181, 220.02857142857147, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(290.73126142595976, 245.9142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(316.3615173674589, 349.4571428571429, 'X[1] <= 0.495\ngini = 0.094\nsamples = 317\nvalue = [478, 25]'),
#  Text(313.30118829981717, 323.57142857142856, 'gini = 0.0\nsamples = 66\nvalue = [108, 0]'),
#  Text(319.4218464351005, 323.57142857142856, 'X[1] <= 0.505\ngini = 0.119\nsamples = 251\nvalue = [370, 25]'),
#  Text(306.03290676416816, 297.6857142857143, 'X[3] <= 214.0\ngini = 0.36\nsamples = 12\nvalue = [13, 4]'),
#  Text(299.9122486288848, 271.8, 'X[4] <= 5.5\ngini = 0.153\nsamples = 8\nvalue = [11, 1]'),
#  Text(296.85191956124316, 245.9142857142857, 'gini = 0.0\nsamples = 6\nvalue = [10, 0]'),
#  Text(302.9725776965265, 245.9142857142857, 'X[5] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(299.9122486288848, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(306.03290676416816, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(312.15356489945157, 271.8, 'X[3] <= 255.5\ngini = 0.48\nsamples = 4\nvalue = [2, 3]'),
#  Text(309.09323583180986, 245.9142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]'),
#  Text(315.2138939670932, 245.9142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(332.8107861060329, 297.6857142857143, 'X[6] <= 0.5\ngini = 0.105\nsamples = 239\nvalue = [357, 21]'),
#  Text(329.75045703839123, 271.8, 'X[4] <= 6.5\ngini = 0.108\nsamples = 233\nvalue = [346, 21]'),
#  Text(326.69012797074953, 245.9142857142857, 'X[3] <= 270.5\ngini = 0.121\nsamples = 208\nvalue = [304, 21]'),
#  Text(312.15356489945157, 220.02857142857147, 'X[1] <= 0.745\ngini = 0.105\nsamples = 196\nvalue = [288, 17]'),
#  Text(309.09323583180986, 194.14285714285717, 'X[2] <= 4.5\ngini = 0.114\nsamples = 177\nvalue = [262, 17]'),
#  Text(293.79159049360146, 168.25714285714287, 'X[1] <= 0.735\ngini = 0.072\nsamples = 135\nvalue = [206, 8]'),
#  Text(283.0804387568556, 142.37142857142857, 'X[5] <= 0.5\ngini = 0.039\nsamples = 128\nvalue = [196, 4]'),
#  Text(276.95978062157224, 116.48571428571432, 'X[4] <= 4.5\ngini = 0.012\nsamples = 103\nvalue = [165, 1]'),
#  Text(273.89945155393053, 90.60000000000002, 'gini = 0.0\nsamples = 72\nvalue = [112, 0]'),
#  Text(280.0201096892139, 90.60000000000002, 'X[0] <= 0.715\ngini = 0.036\nsamples = 31\nvalue = [53, 1]'),
#  Text(276.95978062157224, 64.71428571428572, 'gini = 0.0\nsamples = 23\nvalue = [44, 0]'),
#  Text(283.0804387568556, 64.71428571428572, 'X[3] <= 181.0\ngini = 0.18\nsamples = 8\nvalue = [9, 1]'),
#  Text(280.0201096892139, 38.82857142857142, 'X[3] <= 142.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(276.95978062157224, 12.942857142857179, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(283.0804387568556, 12.942857142857179, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(286.14076782449723, 38.82857142857142, 'gini = 0.0\nsamples = 4\nvalue = [6, 0]'),
#  Text(289.20109689213893, 116.48571428571432, 'X[0] <= 0.145\ngini = 0.161\nsamples = 25\nvalue = [31, 3]'),
#  Text(286.14076782449723, 90.60000000000002, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]'),
#  Text(292.26142595978064, 90.60000000000002, 'gini = 0.0\nsamples = 23\nvalue = [31, 0]'),
#  Text(304.50274223034734, 142.37142857142857, 'X[4] <= 4.5\ngini = 0.408\nsamples = 7\nvalue = [10, 4]'),
#  Text(301.4424131627057, 116.48571428571432, 'X[0] <= 0.785\ngini = 0.494\nsamples = 5\nvalue = [5, 4]'),
#  Text(298.382084095064, 90.60000000000002, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(304.50274223034734, 90.60000000000002, 'X[5] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 4]'),
#  Text(301.4424131627057, 64.71428571428572, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]'),
#  Text(307.56307129798904, 64.71428571428572, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(307.56307129798904, 116.48571428571432, 'gini = 0.0\nsamples = 2\nvalue = [5, 0]'),
#  Text(324.39488117001827, 168.25714285714287, 'X[1] <= 0.545\ngini = 0.239\nsamples = 42\nvalue = [56, 9]'),
#  Text(316.7440585009141, 142.37142857142857, 'X[1] <= 0.53\ngini = 0.48\nsamples = 6\nvalue = [6, 4]'),
#  Text(313.6837294332724, 116.48571428571432, 'gini = 0.0\nsamples = 4\nvalue = [6, 0]'),
#  Text(319.80438756855574, 116.48571428571432, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]'),
#  Text(332.0457038391225, 142.37142857142857, 'X[4] <= 5.5\ngini = 0.165\nsamples = 36\nvalue = [50, 5]'),
#  Text(325.92504570383915, 116.48571428571432, 'X[0] <= 0.87\ngini = 0.111\nsamples = 33\nvalue = [48, 3]'),
#  Text(322.86471663619744, 90.60000000000002, 'gini = 0.0\nsamples = 27\nvalue = [40, 0]'),
#  Text(328.9853747714808, 90.60000000000002, 'X[1] <= 0.685\ngini = 0.397\nsamples = 6\nvalue = [8, 3]'),
#  Text(325.92504570383915, 64.71428571428572, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]'),
#  Text(332.0457038391225, 64.71428571428572, 'X[0] <= 0.93\ngini = 0.49\nsamples = 4\nvalue = [4, 3]'),
#  Text(328.9853747714808, 38.82857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]'),
#  Text(335.10603290676414, 38.82857142857142, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]'),
#  Text(338.16636197440585, 116.48571428571432, 'X[0] <= 0.865\ngini = 0.5\nsamples = 3\nvalue = [2, 2]'),
#  Text(335.10603290676414, 90.60000000000002, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(341.22669104204755, 90.60000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(315.2138939670932, 194.14285714285717, 'gini = 0.0\nsamples = 19\nvalue = [26, 0]'),
#  Text(341.22669104204755, 220.02857142857147, 'X[4] <= 4.5\ngini = 0.32\nsamples = 12\nvalue = [16, 4]'),
#  Text(335.10603290676414, 194.14285714285717, 'X[0] <= 0.495\ngini = 0.444\nsamples = 4\nvalue = [6, 3]'),
#  Text(332.0457038391225, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [0, 3]'),
#  Text(338.16636197440585, 168.25714285714287, 'gini = 0.0\nsamples = 3\nvalue = [6, 0]'),
#  Text(347.3473491773309, 194.14285714285717, 'X[2] <= 3.5\ngini = 0.165\nsamples = 8\nvalue = [10, 1]'),
#  Text(344.2870201096892, 168.25714285714287, 'X[0] <= 0.485\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(341.22669104204755, 142.37142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(347.3473491773309, 142.37142857142857, 'X[0] <= 0.74\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(344.2870201096892, 116.48571428571432, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(350.4076782449726, 116.48571428571432, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(350.4076782449726, 168.25714285714287, 'gini = 0.0\nsamples = 5\nvalue = [8, 0]'),
#  Text(332.8107861060329, 245.9142857142857, 'gini = 0.0\nsamples = 25\nvalue = [42, 0]'),
#  Text(335.8711151736746, 271.8, 'gini = 0.0\nsamples = 6\nvalue = [11, 0]'),
#  Text(381.0109689213894, 401.22857142857146, 'X[3] <= 162.0\ngini = 0.122\nsamples = 147\nvalue = [200, 14]'),
#  Text(365.709323583181, 375.34285714285716, 'X[4] <= 2.5\ngini = 0.21\nsamples = 44\nvalue = [59, 8]'),
#  Text(362.6489945155393, 349.4571428571429, 'gini = 0.0\nsamples = 6\nvalue = [13, 0]'),
#  Text(368.76965265082265, 349.4571428571429, 'X[0] <= 0.68\ngini = 0.252\nsamples = 38\nvalue = [46, 8]'),
#  Text(362.6489945155393, 323.57142857142856, 'X[4] <= 3.5\ngini = 0.1\nsamples = 26\nvalue = [36, 2]'),
#  Text(359.5886654478976, 297.6857142857143, 'gini = 0.0\nsamples = 8\nvalue = [12, 0]'),
#  Text(365.709323583181, 297.6857142857143, 'X[1] <= 0.65\ngini = 0.142\nsamples = 18\nvalue = [24, 2]'),
#  Text(362.6489945155393, 271.8, 'X[1] <= 0.615\ngini = 0.231\nsamples = 12\nvalue = [13, 2]'),
#  Text(359.5886654478976, 245.9142857142857, 'X[3] <= 122.5\ngini = 0.133\nsamples = 11\nvalue = [13, 1]'),
#  Text(356.52833638025595, 220.02857142857147, 'gini = 0.0\nsamples = 7\nvalue = [9, 0]'),
#  Text(362.6489945155393, 220.02857142857147, 'X[0] <= 0.16\ngini = 0.32\nsamples = 4\nvalue = [4, 1]'),
#  Text(359.5886654478976, 194.14285714285717, 'X[1] <= 0.555\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(356.52833638025595, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(362.6489945155393, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(365.709323583181, 194.14285714285717, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(365.709323583181, 245.9142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(368.76965265082265, 271.8, 'gini = 0.0\nsamples = 6\nvalue = [11, 0]'),
#  Text(374.89031078610606, 323.57142857142856, 'X[0] <= 0.715\ngini = 0.469\nsamples = 12\nvalue = [10, 6]'),
#  Text(371.82998171846435, 297.6857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(377.9506398537477, 297.6857142857143, 'X[1] <= 0.68\ngini = 0.408\nsamples = 11\nvalue = [10, 4]'),
#  Text(374.89031078610606, 271.8, 'gini = 0.0\nsamples = 8\nvalue = [10, 0]'),
#  Text(381.0109689213894, 271.8, 'gini = 0.0\nsamples = 3\nvalue = [0, 4]'),
#  Text(396.3126142595978, 375.34285714285716, 'X[3] <= 212.5\ngini = 0.078\nsamples = 103\nvalue = [141, 6]'),
#  Text(393.2522851919561, 349.4571428571429, 'gini = 0.0\nsamples = 45\nvalue = [65, 0]'),
#  Text(399.3729433272395, 349.4571428571429, 'X[3] <= 218.5\ngini = 0.136\nsamples = 58\nvalue = [76, 6]'),
#  Text(393.2522851919561, 323.57142857142856, 'X[4] <= 4.5\ngini = 0.408\nsamples = 10\nvalue = [10, 4]'),
#  Text(390.19195612431446, 297.6857142857143, 'X[8] <= 0.5\ngini = 0.32\nsamples = 4\nvalue = [1, 4]'),
#  Text(387.13162705667276, 271.8, 'gini = 0.0\nsamples = 3\nvalue = [0, 4]'),
#  Text(393.2522851919561, 271.8, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(396.3126142595978, 297.6857142857143, 'gini = 0.0\nsamples = 6\nvalue = [9, 0]'),
#  Text(405.49360146252286, 323.57142857142856, 'X[3] <= 264.0\ngini = 0.057\nsamples = 48\nvalue = [66, 2]'),
#  Text(402.43327239488116, 297.6857142857143, 'gini = 0.0\nsamples = 28\nvalue = [41, 0]'),
#  Text(408.5539305301645, 297.6857142857143, 'X[3] <= 267.0\ngini = 0.137\nsamples = 20\nvalue = [25, 2]'),
#  Text(405.49360146252286, 271.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(411.6142595978062, 271.8, 'X[3] <= 280.5\ngini = 0.074\nsamples = 19\nvalue = [25, 1]'),
#  Text(408.5539305301645, 245.9142857142857, 'gini = 0.0\nsamples = 11\nvalue = [16, 0]'),
#  Text(414.6745886654479, 245.9142857142857, 'X[1] <= 0.685\ngini = 0.18\nsamples = 8\nvalue = [9, 1]'),
#  Text(411.6142595978062, 220.02857142857147, 'gini = 0.0\nsamples = 7\nvalue = [9, 0]'),
#  Text(417.73491773308956, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(319.46966407678246, 427.11428571428576, 'gini = 0.0\nsamples = 3\nvalue = [0, 7]'),
#  Text(322.5299931444241, 453.0, 'gini = 0.0\nsamples = 9\nvalue = [0, 13]'),
#  Text(703.3736003199268, 478.8857142857143, 'X[5] <= 0.5\ngini = 0.419\nsamples = 2701\nvalue = [3004, 1278]'),
#  Text(598.8203267824497, 453.0, 'X[0] <= 0.115\ngini = 0.44\nsamples = 2366\nvalue = [2523, 1223]'),
#  Text(595.759997714808, 427.11428571428576, 'gini = 0.0\nsamples = 360\nvalue = [0, 591]'),
#  Text(601.8806558500914, 427.11428571428576, 'X[0] <= 0.715\ngini = 0.32\nsamples = 2006\nvalue = [2523, 632]'),
#  Text(519.3952239488117, 401.22857142857146, 'X[3] <= 290.5\ngini = 0.087\nsamples = 802\nvalue = [1207, 58]'),
#  Text(516.33489488117, 375.34285714285716, 'X[0] <= 0.475\ngini = 0.085\nsamples = 800\nvalue = [1207, 56]'),
#  Text(466.70018281535647, 349.4571428571429, 'X[0] <= 0.305\ngini = 0.204\nsamples = 189\nvalue = [268, 35]'),
#  Text(440.6873857404022, 323.57142857142856, 'X[1] <= 0.845\ngini = 0.104\nsamples = 133\nvalue = [188, 11]'),
#  Text(433.03656307129796, 297.6857142857143, 'X[4] <= 3.5\ngini = 0.23\nsamples = 48\nvalue = [59, 9]'),
#  Text(429.9762340036563, 271.8, 'X[8] <= 0.5\ngini = 0.49\nsamples = 14\nvalue = [12, 9]'),
#  Text(426.9159049360146, 245.9142857142857, 'X[7] <= 0.5\ngini = 0.499\nsamples = 12\nvalue = [10, 9]'),
#  Text(423.85557586837297, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(429.9762340036563, 220.02857142857147, 'X[3] <= 157.0\ngini = 0.498\nsamples = 11\nvalue = [8, 9]'),
#  Text(426.9159049360146, 194.14285714285717, 'gini = 0.0\nsamples = 3\nvalue = [0, 4]'),
#  Text(433.03656307129796, 194.14285714285717, 'X[2] <= 4.5\ngini = 0.473\nsamples = 8\nvalue = [8, 5]'),
#  Text(429.9762340036563, 168.25714285714287, 'gini = 0.0\nsamples = 3\nvalue = [5, 0]'),
#  Text(436.09689213893967, 168.25714285714287, 'X[1] <= 0.82\ngini = 0.469\nsamples = 5\nvalue = [3, 5]'),
#  Text(433.03656307129796, 142.37142857142857, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(439.15722120658137, 142.37142857142857, 'gini = 0.0\nsamples = 3\nvalue = [0, 5]'),
#  Text(433.03656307129796, 245.9142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(436.09689213893967, 271.8, 'gini = 0.0\nsamples = 34\nvalue = [47, 0]'),
#  Text(448.3382084095064, 297.6857142857143, 'X[0] <= 0.125\ngini = 0.03\nsamples = 85\nvalue = [129, 2]'),
#  Text(442.217550274223, 271.8, 'X[8] <= 0.5\ngini = 0.444\nsamples = 2\nvalue = [2, 1]'),
#  Text(439.15722120658137, 245.9142857142857, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(445.2778793418647, 245.9142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(454.45886654478977, 271.8, 'X[4] <= 4.5\ngini = 0.016\nsamples = 83\nvalue = [127, 1]'),
#  Text(451.39853747714807, 245.9142857142857, 'X[0] <= 0.195\ngini = 0.029\nsamples = 42\nvalue = [68, 1]'),
#  Text(448.3382084095064, 220.02857142857147, 'X[3] <= 195.5\ngini = 0.059\nsamples = 22\nvalue = [32, 1]'),
#  Text(445.2778793418647, 194.14285714285717, 'X[3] <= 185.0\ngini = 0.18\nsamples = 8\nvalue = [9, 1]'),
#  Text(442.217550274223, 168.25714285714287, 'gini = 0.0\nsamples = 6\nvalue = [8, 0]'),
#  Text(448.3382084095064, 168.25714285714287, 'X[0] <= 0.18\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(445.2778793418647, 142.37142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(451.39853747714807, 142.37142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(451.39853747714807, 194.14285714285717, 'gini = 0.0\nsamples = 14\nvalue = [23, 0]'),
#  Text(454.45886654478977, 220.02857142857147, 'gini = 0.0\nsamples = 20\nvalue = [36, 0]'),
#  Text(457.5191956124314, 245.9142857142857, 'gini = 0.0\nsamples = 41\nvalue = [59, 0]'),
#  Text(492.7129798903108, 323.57142857142856, 'X[4] <= 4.5\ngini = 0.355\nsamples = 56\nvalue = [80, 24]'),
#  Text(482.0018281535649, 297.6857142857143, 'X[2] <= 4.5\ngini = 0.432\nsamples = 31\nvalue = [39, 18]'),
#  Text(469.7605118829982, 271.8, 'X[1] <= 0.83\ngini = 0.472\nsamples = 11\nvalue = [8, 13]'),
#  Text(463.6398537477148, 245.9142857142857, 'X[2] <= 3.5\ngini = 0.219\nsamples = 3\nvalue = [1, 7]'),
#  Text(460.5795246800731, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(466.70018281535647, 220.02857142857147, 'gini = 0.0\nsamples = 2\nvalue = [0, 7]'),
#  Text(475.8811700182815, 245.9142857142857, 'X[0] <= 0.345\ngini = 0.497\nsamples = 8\nvalue = [7, 6]'),
#  Text(472.8208409506399, 220.02857142857147, 'gini = 0.0\nsamples = 4\nvalue = [6, 0]'),
#  Text(478.9414990859232, 220.02857142857147, 'X[3] <= 248.5\ngini = 0.245\nsamples = 4\nvalue = [1, 6]'),
#  Text(475.8811700182815, 194.14285714285717, 'gini = 0.0\nsamples = 3\nvalue = [0, 6]'),
#  Text(482.0018281535649, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(494.24314442413163, 271.8, 'X[3] <= 124.5\ngini = 0.239\nsamples = 20\nvalue = [31, 5]'),
#  Text(491.1828153564899, 245.9142857142857, 'gini = 0.0\nsamples = 4\nvalue = [9, 0]'),
#  Text(497.30347349177333, 245.9142857142857, 'X[1] <= 0.965\ngini = 0.302\nsamples = 16\nvalue = [22, 5]'),
#  Text(491.1828153564899, 220.02857142857147, 'X[0] <= 0.325\ngini = 0.159\nsamples = 13\nvalue = [21, 2]'),
#  Text(488.1224862888483, 194.14285714285717, 'X[3] <= 188.5\ngini = 0.5\nsamples = 2\nvalue = [2, 2]'),
#  Text(485.0621572212066, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(491.1828153564899, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(494.24314442413163, 194.14285714285717, 'gini = 0.0\nsamples = 11\nvalue = [19, 0]'),
#  Text(503.4241316270567, 220.02857142857147, 'X[4] <= 3.0\ngini = 0.375\nsamples = 3\nvalue = [1, 3]'),
#  Text(500.363802559415, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(506.4844606946983, 194.14285714285717, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]'),
#  Text(503.4241316270567, 297.6857142857143, 'X[2] <= 5.5\ngini = 0.223\nsamples = 25\nvalue = [41, 6]'),
#  Text(500.363802559415, 271.8, 'gini = 0.0\nsamples = 17\nvalue = [33, 0]'),
#  Text(506.4844606946983, 271.8, 'X[3] <= 165.0\ngini = 0.49\nsamples = 8\nvalue = [8, 6]'),
#  Text(503.4241316270567, 245.9142857142857, 'gini = 0.0\nsamples = 4\nvalue = [0, 6]'),
#  Text(509.54478976234003, 245.9142857142857, 'gini = 0.0\nsamples = 4\nvalue = [8, 0]'),
#  Text(565.9696069469835, 349.4571428571429, 'X[8] <= 0.5\ngini = 0.043\nsamples = 611\nvalue = [939, 21]'),
#  Text(535.1750457038391, 323.57142857142856, 'X[3] <= 136.5\ngini = 0.061\nsamples = 327\nvalue = [490, 16]'),
#  Text(521.7861060329068, 297.6857142857143, 'X[2] <= 5.5\ngini = 0.191\nsamples = 18\nvalue = [25, 3]'),
#  Text(518.725776965265, 271.8, 'X[1] <= 0.895\ngini = 0.074\nsamples = 17\nvalue = [25, 1]'),
#  Text(515.6654478976234, 245.9142857142857, 'X[4] <= 3.5\ngini = 0.165\nsamples = 8\nvalue = [10, 1]'),
#  Text(512.6051188299817, 220.02857142857147, 'gini = 0.0\nsamples = 3\nvalue = [5, 0]'),
#  Text(518.725776965265, 220.02857142857147, 'X[0] <= 0.615\ngini = 0.278\nsamples = 5\nvalue = [5, 1]'),
#  Text(515.6654478976234, 194.14285714285717, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(521.7861060329068, 194.14285714285717, 'X[4] <= 6.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(518.725776965265, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(524.8464351005484, 168.25714285714287, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(521.7861060329068, 245.9142857142857, 'gini = 0.0\nsamples = 9\nvalue = [15, 0]'),
#  Text(524.8464351005484, 271.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(548.5639853747715, 297.6857142857143, 'X[0] <= 0.595\ngini = 0.053\nsamples = 309\nvalue = [465, 13]'),
#  Text(537.0877513711151, 271.8, 'X[0] <= 0.485\ngini = 0.017\nsamples = 153\nvalue = [232, 2]'),
#  Text(534.0274223034735, 245.9142857142857, 'X[3] <= 213.5\ngini = 0.198\nsamples = 11\nvalue = [16, 2]'),
#  Text(530.9670932358318, 220.02857142857147, 'gini = 0.0\nsamples = 6\nvalue = [11, 0]'),
#  Text(537.0877513711151, 220.02857142857147, 'X[2] <= 3.5\ngini = 0.408\nsamples = 5\nvalue = [5, 2]'),
#  Text(534.0274223034735, 194.14285714285717, 'X[3] <= 249.0\ngini = 0.5\nsamples = 3\nvalue = [2, 2]'),
#  Text(530.9670932358318, 168.25714285714287, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(537.0877513711151, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(540.1480804387569, 194.14285714285717, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(540.1480804387569, 245.9142857142857, 'gini = 0.0\nsamples = 142\nvalue = [216, 0]'),
#  Text(560.0402193784278, 271.8, 'X[2] <= 5.5\ngini = 0.086\nsamples = 156\nvalue = [233, 11]'),
#  Text(549.329067641682, 245.9142857142857, 'X[7] <= 0.5\ngini = 0.041\nsamples = 152\nvalue = [231, 5]'),
#  Text(546.2687385740402, 220.02857142857147, 'gini = 0.0\nsamples = 29\nvalue = [45, 0]'),
#  Text(552.3893967093236, 220.02857142857147, 'X[0] <= 0.615\ngini = 0.051\nsamples = 123\nvalue = [186, 5]'),
#  Text(546.2687385740402, 194.14285714285717, 'X[1] <= 0.87\ngini = 0.153\nsamples = 29\nvalue = [44, 4]'),
#  Text(543.2084095063985, 168.25714285714287, 'X[4] <= 3.5\ngini = 0.231\nsamples = 19\nvalue = [26, 4]'),
#  Text(540.1480804387569, 142.37142857142857, 'X[3] <= 246.0\ngini = 0.133\nsamples = 18\nvalue = [26, 2]'),
#  Text(537.0877513711151, 116.48571428571432, 'gini = 0.0\nsamples = 10\nvalue = [16, 0]'),
#  Text(543.2084095063985, 116.48571428571432, 'X[3] <= 251.0\ngini = 0.278\nsamples = 8\nvalue = [10, 2]'),
#  Text(540.1480804387569, 90.60000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(546.2687385740402, 90.60000000000002, 'gini = 0.0\nsamples = 7\nvalue = [10, 0]'),
#  Text(546.2687385740402, 142.37142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(549.329067641682, 168.25714285714287, 'gini = 0.0\nsamples = 10\nvalue = [18, 0]'),
#  Text(558.510054844607, 194.14285714285717, 'X[2] <= 4.5\ngini = 0.014\nsamples = 94\nvalue = [142, 1]'),
#  Text(555.4497257769652, 168.25714285714287, 'gini = 0.0\nsamples = 80\nvalue = [119, 0]'),
#  Text(561.5703839122486, 168.25714285714287, 'X[4] <= 4.0\ngini = 0.08\nsamples = 14\nvalue = [23, 1]'),
#  Text(558.510054844607, 142.37142857142857, 'gini = 0.0\nsamples = 11\nvalue = [21, 0]'),
#  Text(564.6307129798903, 142.37142857142857, 'X[3] <= 235.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(561.5703839122486, 116.48571428571432, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(567.6910420475319, 116.48571428571432, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(570.7513711151737, 245.9142857142857, 'X[1] <= 0.87\ngini = 0.375\nsamples = 4\nvalue = [2, 6]'),
#  Text(567.6910420475319, 220.02857142857147, 'X[3] <= 246.0\ngini = 0.5\nsamples = 3\nvalue = [2, 2]'),
#  Text(564.6307129798903, 194.14285714285717, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(570.7513711151737, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(573.8117001828153, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [0, 4]'),
#  Text(596.764168190128, 323.57142857142856, 'X[1] <= 0.855\ngini = 0.022\nsamples = 284\nvalue = [449, 5]'),
#  Text(593.7038391224863, 297.6857142857143, 'gini = 0.0\nsamples = 93\nvalue = [152, 0]'),
#  Text(599.8244972577696, 297.6857142857143, 'X[1] <= 0.875\ngini = 0.033\nsamples = 191\nvalue = [297, 5]'),
#  Text(589.1133455210238, 271.8, 'X[1] <= 0.865\ngini = 0.165\nsamples = 21\nvalue = [30, 3]'),
#  Text(582.9926873857404, 245.9142857142857, 'X[2] <= 4.5\ngini = 0.208\nsamples = 10\nvalue = [15, 2]'),
#  Text(579.9323583180987, 220.02857142857147, 'gini = 0.0\nsamples = 6\nvalue = [11, 0]'),
#  Text(586.053016453382, 220.02857142857147, 'X[4] <= 2.5\ngini = 0.444\nsamples = 4\nvalue = [4, 2]'),
#  Text(582.9926873857404, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(589.1133455210238, 194.14285714285717, 'gini = 0.0\nsamples = 3\nvalue = [4, 0]'),
#  Text(595.2340036563071, 245.9142857142857, 'X[3] <= 175.5\ngini = 0.117\nsamples = 11\nvalue = [15, 1]'),
#  Text(592.1736745886654, 220.02857142857147, 'gini = 0.0\nsamples = 7\nvalue = [11, 0]'),
#  Text(598.2943327239489, 220.02857142857147, 'X[4] <= 3.0\ngini = 0.32\nsamples = 4\nvalue = [4, 1]'),
#  Text(595.2340036563071, 194.14285714285717, 'gini = 0.0\nsamples = 3\nvalue = [4, 0]'),
#  Text(601.3546617915905, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(610.5356489945156, 271.8, 'X[4] <= 2.5\ngini = 0.015\nsamples = 170\nvalue = [267, 2]'),
#  Text(607.4753199268739, 245.9142857142857, 'X[0] <= 0.625\ngini = 0.053\nsamples = 49\nvalue = [72, 2]'),
#  Text(604.4149908592321, 220.02857142857147, 'gini = 0.0\nsamples = 34\nvalue = [47, 0]'),
#  Text(610.5356489945156, 220.02857142857147, 'X[0] <= 0.635\ngini = 0.137\nsamples = 15\nvalue = [25, 2]'),
#  Text(607.4753199268739, 194.14285714285717, 'X[2] <= 3.5\ngini = 0.5\nsamples = 3\nvalue = [2, 2]'),
#  Text(604.4149908592321, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(610.5356489945156, 168.25714285714287, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(613.5959780621572, 194.14285714285717, 'gini = 0.0\nsamples = 12\nvalue = [23, 0]'),
#  Text(613.5959780621572, 245.9142857142857, 'gini = 0.0\nsamples = 121\nvalue = [195, 0]'),
#  Text(522.4555530164533, 375.34285714285716, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(684.3660877513711, 401.22857142857146, 'X[3] <= 218.5\ngini = 0.423\nsamples = 1204\nvalue = [1316, 574]'),
#  Text(656.8231261425959, 375.34285714285716, 'X[8] <= 0.5\ngini = 0.031\nsamples = 542\nvalue = [821, 13]'),
#  Text(640.3738574040219, 349.4571428571429, 'X[3] <= 215.5\ngini = 0.037\nsamples = 312\nvalue = [471, 9]'),
#  Text(630.4277879341864, 323.57142857142856, 'X[4] <= 3.5\ngini = 0.017\nsamples = 300\nvalue = [457, 4]'),
#  Text(619.7166361974406, 297.6857142857143, 'X[1] <= 0.965\ngini = 0.006\nsamples = 229\nvalue = [347, 1]'),
#  Text(616.6563071297988, 271.8, 'gini = 0.0\nsamples = 192\nvalue = [293, 0]'),
#  Text(622.7769652650823, 271.8, 'X[0] <= 0.735\ngini = 0.036\nsamples = 37\nvalue = [54, 1]'),
#  Text(619.7166361974406, 245.9142857142857, 'X[3] <= 181.5\ngini = 0.219\nsamples = 5\nvalue = [7, 1]'),
#  Text(616.6563071297988, 220.02857142857147, 'gini = 0.0\nsamples = 4\nvalue = [7, 0]'),
#  Text(622.7769652650823, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(625.8372943327239, 245.9142857142857, 'gini = 0.0\nsamples = 32\nvalue = [47, 0]'),
#  Text(641.1389396709324, 297.6857142857143, 'X[0] <= 0.735\ngini = 0.052\nsamples = 71\nvalue = [110, 3]'),
#  Text(635.018281535649, 271.8, 'X[3] <= 177.0\ngini = 0.278\nsamples = 5\nvalue = [5, 1]'),
#  Text(631.9579524680073, 245.9142857142857, 'X[0] <= 0.725\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(628.8976234003657, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(635.018281535649, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(638.0786106032907, 245.9142857142857, 'gini = 0.0\nsamples = 3\nvalue = [4, 0]'),
#  Text(647.2595978062158, 271.8, 'X[2] <= 4.5\ngini = 0.037\nsamples = 66\nvalue = [105, 2]'),
#  Text(644.199268738574, 245.9142857142857, 'X[1] <= 0.865\ngini = 0.053\nsamples = 45\nvalue = [71, 2]'),
#  Text(641.1389396709324, 220.02857142857147, 'gini = 0.0\nsamples = 18\nvalue = [29, 0]'),
#  Text(647.2595978062158, 220.02857142857147, 'X[4] <= 4.5\ngini = 0.087\nsamples = 27\nvalue = [42, 2]'),
#  Text(641.1389396709324, 194.14285714285717, 'X[3] <= 151.5\ngini = 0.061\nsamples = 19\nvalue = [31, 1]'),
#  Text(638.0786106032907, 168.25714285714287, 'X[1] <= 0.88\ngini = 0.219\nsamples = 5\nvalue = [7, 1]'),
#  Text(635.018281535649, 142.37142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(641.1389396709324, 142.37142857142857, 'gini = 0.0\nsamples = 4\nvalue = [7, 0]'),
#  Text(644.199268738574, 168.25714285714287, 'gini = 0.0\nsamples = 14\nvalue = [24, 0]'),
#  Text(653.3802559414991, 194.14285714285717, 'X[4] <= 5.5\ngini = 0.153\nsamples = 8\nvalue = [11, 1]'),
#  Text(650.3199268738574, 168.25714285714287, 'X[0] <= 0.855\ngini = 0.278\nsamples = 4\nvalue = [5, 1]'),
#  Text(647.2595978062158, 142.37142857142857, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(653.3802559414991, 142.37142857142857, 'X[1] <= 0.985\ngini = 0.444\nsamples = 2\nvalue = [2, 1]'),
#  Text(650.3199268738574, 116.48571428571432, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(656.4405850091408, 116.48571428571432, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(656.4405850091408, 168.25714285714287, 'gini = 0.0\nsamples = 4\nvalue = [6, 0]'),
#  Text(650.3199268738574, 245.9142857142857, 'gini = 0.0\nsamples = 21\nvalue = [34, 0]'),
#  Text(650.3199268738574, 323.57142857142856, 'X[4] <= 4.5\ngini = 0.388\nsamples = 12\nvalue = [14, 5]'),
#  Text(647.2595978062158, 297.6857142857143, 'gini = 0.0\nsamples = 8\nvalue = [14, 0]'),
#  Text(653.3802559414991, 297.6857142857143, 'gini = 0.0\nsamples = 4\nvalue = [0, 5]'),
#  Text(673.27239488117, 349.4571428571429, 'X[1] <= 0.995\ngini = 0.022\nsamples = 230\nvalue = [350, 4]'),
#  Text(665.6215722120658, 323.57142857142856, 'X[3] <= 216.5\ngini = 0.017\nsamples = 226\nvalue = [347, 3]'),
#  Text(659.5009140767825, 297.6857142857143, 'X[3] <= 205.5\ngini = 0.006\nsamples = 220\nvalue = [340, 1]'),
#  Text(656.4405850091408, 271.8, 'gini = 0.0\nsamples = 194\nvalue = [305, 0]'),
#  Text(662.5612431444241, 271.8, 'X[2] <= 3.5\ngini = 0.054\nsamples = 26\nvalue = [35, 1]'),
#  Text(659.5009140767825, 245.9142857142857, 'gini = 0.0\nsamples = 12\nvalue = [19, 0]'),
#  Text(665.6215722120658, 245.9142857142857, 'X[4] <= 3.5\ngini = 0.111\nsamples = 14\nvalue = [16, 1]'),
#  Text(662.5612431444241, 220.02857142857147, 'gini = 0.0\nsamples = 10\nvalue = [13, 0]'),
#  Text(668.6819012797075, 220.02857142857147, 'X[3] <= 207.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(665.6215722120658, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(671.7422303473492, 194.14285714285717, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(671.7422303473492, 297.6857142857143, 'X[4] <= 5.0\ngini = 0.346\nsamples = 6\nvalue = [7, 2]'),
#  Text(668.6819012797075, 271.8, 'gini = 0.0\nsamples = 4\nvalue = [7, 0]'),
#  Text(674.8025594149908, 271.8, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(680.9232175502742, 323.57142857142856, 'X[3] <= 154.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(677.8628884826326, 297.6857142857143, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(683.9835466179159, 297.6857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(711.9090493601462, 375.34285714285716, 'X[2] <= 3.5\ngini = 0.498\nsamples = 662\nvalue = [495, 561]'),
#  Text(708.8487202925046, 349.4571428571429, 'gini = 0.0\nsamples = 116\nvalue = [190, 0]'),
#  Text(714.9693784277879, 349.4571428571429, 'X[4] <= 4.5\ngini = 0.456\nsamples = 546\nvalue = [305, 561]'),
#  Text(693.1645338208409, 323.57142857142856, 'X[7] <= 0.5\ngini = 0.007\nsamples = 178\nvalue = [290, 1]'),
#  Text(690.1042047531993, 297.6857142857143, 'gini = 0.0\nsamples = 93\nvalue = [142, 0]'),
#  Text(696.2248628884827, 297.6857142857143, 'X[0] <= 0.895\ngini = 0.013\nsamples = 85\nvalue = [148, 1]'),
#  Text(693.1645338208409, 271.8, 'gini = 0.0\nsamples = 54\nvalue = [99, 0]'),
#  Text(699.2851919561243, 271.8, 'X[1] <= 0.945\ngini = 0.039\nsamples = 31\nvalue = [49, 1]'),
#  Text(696.2248628884827, 245.9142857142857, 'gini = 0.0\nsamples = 25\nvalue = [36, 0]'),
#  Text(702.345521023766, 245.9142857142857, 'X[3] <= 270.0\ngini = 0.133\nsamples = 6\nvalue = [13, 1]'),
#  Text(699.2851919561243, 220.02857142857147, 'gini = 0.0\nsamples = 5\nvalue = [13, 0]'),
#  Text(705.4058500914077, 220.02857142857147, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(736.7742230347349, 323.57142857142856, 'X[4] <= 7.0\ngini = 0.051\nsamples = 368\nvalue = [15, 560]'),
#  Text(733.7138939670932, 297.6857142857143, 'X[2] <= 5.5\ngini = 0.038\nsamples = 365\nvalue = [11, 560]'),
#  Text(730.6535648994516, 271.8, 'X[3] <= 221.5\ngini = 0.031\nsamples = 363\nvalue = [9, 560]'),
#  Text(714.5868372943327, 245.9142857142857, 'X[8] <= 0.5\ngini = 0.153\nsamples = 14\nvalue = [2, 22]'),
#  Text(711.526508226691, 220.02857142857147, 'X[0] <= 0.765\ngini = 0.198\nsamples = 12\nvalue = [2, 16]'),
#  Text(708.4661791590494, 194.14285714285717, 'gini = 0.0\nsamples = 6\nvalue = [0, 9]'),
#  Text(714.5868372943327, 194.14285714285717, 'X[0] <= 0.8\ngini = 0.346\nsamples = 6\nvalue = [2, 7]'),
#  Text(711.526508226691, 168.25714285714287, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(717.6471663619744, 168.25714285714287, 'gini = 0.0\nsamples = 5\nvalue = [0, 7]'),
#  Text(717.6471663619744, 220.02857142857147, 'gini = 0.0\nsamples = 2\nvalue = [0, 6]'),
#  Text(746.7202925045704, 245.9142857142857, 'X[4] <= 5.5\ngini = 0.025\nsamples = 349\nvalue = [7, 538]'),
#  Text(732.9488117001828, 220.02857142857147, 'X[1] <= 0.835\ngini = 0.014\nsamples = 276\nvalue = [3, 419]'),
#  Text(726.8281535648995, 194.14285714285717, 'X[3] <= 265.0\ngini = 0.111\nsamples = 18\nvalue = [2, 32]'),
#  Text(723.7678244972577, 168.25714285714287, 'gini = 0.0\nsamples = 12\nvalue = [0, 18]'),
#  Text(729.8884826325411, 168.25714285714287, 'X[3] <= 266.5\ngini = 0.219\nsamples = 6\nvalue = [2, 14]'),
#  Text(726.8281535648995, 142.37142857142857, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(732.9488117001828, 142.37142857142857, 'gini = 0.0\nsamples = 5\nvalue = [0, 14]'),
#  Text(739.0694698354662, 194.14285714285717, 'X[1] <= 0.955\ngini = 0.005\nsamples = 258\nvalue = [1, 387]'),
#  Text(736.0091407678245, 168.25714285714287, 'gini = 0.0\nsamples = 153\nvalue = [0, 229]'),
#  Text(742.1297989031078, 168.25714285714287, 'X[8] <= 0.5\ngini = 0.012\nsamples = 105\nvalue = [1, 158]'),
#  Text(739.0694698354662, 142.37142857142857, 'X[1] <= 0.965\ngini = 0.024\nsamples = 60\nvalue = [1, 81]'),
#  Text(736.0091407678245, 116.48571428571432, 'X[2] <= 4.5\ngini = 0.245\nsamples = 6\nvalue = [1, 6]'),
#  Text(732.9488117001828, 90.60000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(739.0694698354662, 90.60000000000002, 'X[3] <= 252.5\ngini = 0.278\nsamples = 5\nvalue = [1, 5]'),
#  Text(736.0091407678245, 64.71428571428572, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(742.1297989031078, 64.71428571428572, 'gini = 0.0\nsamples = 4\nvalue = [0, 5]'),
#  Text(742.1297989031078, 116.48571428571432, 'gini = 0.0\nsamples = 54\nvalue = [0, 75]'),
#  Text(745.1901279707496, 142.37142857142857, 'gini = 0.0\nsamples = 45\nvalue = [0, 77]'),
#  Text(760.4917733089579, 220.02857142857147, 'X[7] <= 0.5\ngini = 0.063\nsamples = 73\nvalue = [4, 119]'),
#  Text(757.4314442413163, 194.14285714285717, 'X[0] <= 0.92\ngini = 0.238\nsamples = 20\nvalue = [4, 25]'),
#  Text(754.3711151736746, 168.25714285714287, 'X[1] <= 0.815\ngini = 0.137\nsamples = 18\nvalue = [2, 25]'),
#  Text(751.3107861060329, 142.37142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(757.4314442413163, 142.37142857142857, 'X[3] <= 241.5\ngini = 0.074\nsamples = 17\nvalue = [1, 25]'),
#  Text(754.3711151736746, 116.48571428571432, 'X[2] <= 4.5\ngini = 0.375\nsamples = 3\nvalue = [1, 3]'),
#  Text(751.3107861060329, 90.60000000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(757.4314442413163, 90.60000000000002, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]'),
#  Text(760.4917733089579, 116.48571428571432, 'gini = 0.0\nsamples = 14\nvalue = [0, 22]'),
#  Text(760.4917733089579, 168.25714285714287, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(763.5521023765996, 194.14285714285717, 'gini = 0.0\nsamples = 53\nvalue = [0, 94]'),
#  Text(736.7742230347349, 271.8, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(739.8345521023766, 297.6857142857143, 'gini = 0.0\nsamples = 3\nvalue = [4, 0]'),
#  Text(807.926873857404, 453.0, 'X[0] <= 0.115\ngini = 0.184\nsamples = 335\nvalue = [481, 55]'),
#  Text(804.8665447897623, 427.11428571428576, 'gini = 0.0\nsamples = 15\nvalue = [0, 22]'),
#  Text(810.9872029250457, 427.11428571428576, 'X[1] <= 0.995\ngini = 0.12\nsamples = 320\nvalue = [481, 33]'),
#  Text(794.1553930530165, 401.22857142857146, 'X[6] <= 0.5\ngini = 0.082\nsamples = 303\nvalue = [470, 21]'),
#  Text(791.0950639853747, 375.34285714285716, 'X[2] <= 3.5\ngini = 0.087\nsamples = 286\nvalue = [438, 21]'),
#  Text(788.0347349177331, 349.4571428571429, 'gini = 0.0\nsamples = 112\nvalue = [178, 0]'),
#  Text(794.1553930530165, 349.4571428571429, 'X[3] <= 217.5\ngini = 0.138\nsamples = 174\nvalue = [260, 21]'),
#  Text(778.853747714808, 323.57142857142856, 'X[8] <= 0.5\ngini = 0.013\nsamples = 95\nvalue = [149, 1]'),
#  Text(775.7934186471664, 297.6857142857143, 'X[4] <= 3.5\ngini = 0.019\nsamples = 65\nvalue = [101, 1]'),
#  Text(772.7330895795246, 271.8, 'gini = 0.0\nsamples = 53\nvalue = [85, 0]'),
#  Text(778.853747714808, 271.8, 'X[4] <= 4.5\ngini = 0.111\nsamples = 12\nvalue = [16, 1]'),
#  Text(775.7934186471664, 245.9142857142857, 'X[2] <= 4.5\ngini = 0.245\nsamples = 5\nvalue = [6, 1]'),
#  Text(772.7330895795246, 220.02857142857147, 'X[0] <= 0.385\ngini = 0.32\nsamples = 3\nvalue = [4, 1]'),
#  Text(769.672760511883, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(775.7934186471664, 194.14285714285717, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]'),
#  Text(778.853747714808, 220.02857142857147, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(781.9140767824497, 245.9142857142857, 'gini = 0.0\nsamples = 7\nvalue = [10, 0]'),
#  Text(781.9140767824497, 297.6857142857143, 'gini = 0.0\nsamples = 30\nvalue = [48, 0]'),
#  Text(809.4570383912248, 323.57142857142856, 'X[4] <= 4.5\ngini = 0.259\nsamples = 79\nvalue = [111, 20]'),
#  Text(797.2157221206581, 297.6857142857143, 'X[8] <= 0.5\ngini = 0.062\nsamples = 56\nvalue = [91, 3]'),
#  Text(791.0950639853747, 271.8, 'X[4] <= 3.5\ngini = 0.064\nsamples = 34\nvalue = [58, 2]'),
#  Text(788.0347349177331, 245.9142857142857, 'gini = 0.0\nsamples = 30\nvalue = [52, 0]'),
#  Text(794.1553930530165, 245.9142857142857, 'X[2] <= 4.5\ngini = 0.375\nsamples = 4\nvalue = [6, 2]'),
#  Text(791.0950639853747, 220.02857142857147, 'X[0] <= 0.71\ngini = 0.5\nsamples = 2\nvalue = [2, 2]'),
#  Text(788.0347349177331, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(794.1553930530165, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(797.2157221206581, 220.02857142857147, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]'),
#  Text(803.3363802559415, 271.8, 'X[3] <= 220.0\ngini = 0.057\nsamples = 22\nvalue = [33, 1]'),
#  Text(800.2760511882998, 245.9142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(806.3967093235832, 245.9142857142857, 'gini = 0.0\nsamples = 21\nvalue = [33, 0]'),
#  Text(821.6983546617915, 297.6857142857143, 'X[1] <= 0.895\ngini = 0.497\nsamples = 23\nvalue = [20, 17]'),
#  Text(815.5776965265082, 271.8, 'X[4] <= 6.5\ngini = 0.401\nsamples = 13\nvalue = [5, 13]'),
#  Text(812.5173674588665, 245.9142857142857, 'X[1] <= 0.835\ngini = 0.305\nsamples = 12\nvalue = [3, 13]'),
#  Text(809.4570383912248, 220.02857142857147, 'X[3] <= 221.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(806.3967093235832, 194.14285714285717, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(812.5173674588665, 194.14285714285717, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(815.5776965265082, 220.02857142857147, 'gini = 0.0\nsamples = 8\nvalue = [0, 12]'),
#  Text(818.6380255941499, 245.9142857142857, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(827.819012797075, 271.8, 'X[1] <= 0.92\ngini = 0.332\nsamples = 10\nvalue = [15, 4]'),
#  Text(824.7586837294333, 245.9142857142857, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]'),
#  Text(830.8793418647166, 245.9142857142857, 'X[2] <= 5.5\ngini = 0.391\nsamples = 8\nvalue = [11, 4]'),
#  Text(827.819012797075, 220.02857142857147, 'X[0] <= 0.9\ngini = 0.463\nsamples = 5\nvalue = [7, 4]'),
#  Text(824.7586837294333, 194.14285714285717, 'gini = 0.0\nsamples = 3\nvalue = [0, 4]'),
#  Text(830.8793418647166, 194.14285714285717, 'gini = 0.0\nsamples = 2\nvalue = [7, 0]'),
#  Text(833.9396709323584, 220.02857142857147, 'gini = 0.0\nsamples = 3\nvalue = [4, 0]'),
#  Text(797.2157221206581, 375.34285714285716, 'gini = 0.0\nsamples = 17\nvalue = [32, 0]'),
#  Text(827.819012797075, 401.22857142857146, 'X[0] <= 0.77\ngini = 0.499\nsamples = 17\nvalue = [11, 12]'),
#  Text(824.7586837294333, 375.34285714285716, 'gini = 0.0\nsamples = 5\nvalue = [6, 0]'),
#  Text(830.8793418647166, 375.34285714285716, 'X[0] <= 0.935\ngini = 0.415\nsamples = 12\nvalue = [5, 12]'),
#  Text(827.819012797075, 349.4571428571429, 'X[2] <= 5.5\ngini = 0.142\nsamples = 9\nvalue = [1, 12]'),
#  Text(824.7586837294333, 323.57142857142856, 'gini = 0.0\nsamples = 7\nvalue = [0, 11]'),
#  Text(830.8793418647166, 323.57142857142856, 'X[8] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(827.819012797075, 297.6857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(833.9396709323584, 297.6857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(833.9396709323584, 349.4571428571429, 'gini = 0.0\nsamples = 3\nvalue = [4, 0]')]

# %%
plt.figure(figsize=(30,15))
for i in range(1):
    tree.plot_tree(model.estimators_[i],filled=True)

# %% [markdown]
# ### Model Evaluation:

# %%
model.score(X_test,y_test)
# Out:
# 0.9915555555555555

# %%
X_test[:1]
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
model.predict(X_test[:1])
# Out:
# array([0], dtype=int64)

# %%
df2.loc[14119]
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,model.predict(X_test))
cm
# Out:
# array([[3383,    5],
#        [  33, 1079]], dtype=int64)

# %%
sns.heatmap(cm,annot=True)
plt.xlabel("Predicted Value")
plt.ylabel("True Value")
plt.show()

# %% [markdown]
# # Model Gives 99.15 % Accuracy Score.
